# %%
# %pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.5 MB 413.0 kB/s eta 0:00:27
#    - -------------------------------------- 0.5/11.5 MB 413.0 kB/s eta 0:00:27
#    - -------------------------------------- 0.5/11.5 MB 413.0 kB/s eta 0:00:27
#    -- ------------------------------------- 0.8/11.5 MB 415.8 kB/s eta 0:00:26
#    -- ------------------------------------- 0.8/11.5 MB 415.8 kB/s eta 0:00:26
#    -- ------------------------------------- 0.8/11.5 MB 415.8 kB/s eta 0:00:26
#    -- ------------------------------------- 0.8/11.5 MB 415.8 kB/s eta 0:00:26
# ...

# %%
import pandas as pd

# %%
columname = ['index', 'date', 'orderID', 'status']

# %%
wo = pd.read_csv('data/retail_db/orders/part-00000', names= columname)

# %%
wo
# Out:
#        index                   date  orderID           status order_month
# 0          1  2013-07-25 00:00:00.0    11599           CLOSED     2013-07
# 1          2  2013-07-25 00:00:00.0      256  PENDING_PAYMENT     2013-07
# 2          3  2013-07-25 00:00:00.0    12111         COMPLETE     2013-07
# 3          4  2013-07-25 00:00:00.0     8827           CLOSED     2013-07
# 4          5  2013-07-25 00:00:00.0    11318         COMPLETE     2013-07
# ...      ...                    ...      ...              ...         ...
# 68878  68879  2014-07-09 00:00:00.0      778         COMPLETE     2014-07
# 68879  68880  2014-07-13 00:00:00.0     1117         COMPLETE     2014-07
# 68880  68881  2014-07-19 00:00:00.0     2518  PENDING_PAYMENT     2014-07
# 68881  68882  2014-07-22 00:00:00.0    10000          ON_HOLD     2014-07
# 68882  68883  2014-07-23 00:00:00.0     5533         COMPLETE     2014-07
#
# [68883 rows x 5 columns]

# %%
wo.columns
# Out:
# Index(['index', 'date', 'orderID', 'status'], dtype='object')

# %%
wo['orderID'].unique()
# Out:
# array([11599,   256, 12111, ..., 10605,  8537, 10347], shape=(12405,))

# %%
wo.query('status == "COMPLETE" or status == "CLOSED"')
# Out:
#        index                   date  orderID    status
# 0          1  2013-07-25 00:00:00.0    11599    CLOSED
# 2          3  2013-07-25 00:00:00.0    12111  COMPLETE
# 3          4  2013-07-25 00:00:00.0     8827    CLOSED
# 4          5  2013-07-25 00:00:00.0    11318  COMPLETE
# 5          6  2013-07-25 00:00:00.0     7130  COMPLETE
# ...      ...                    ...      ...       ...
# 68875  68876  2014-07-06 00:00:00.0     4124  COMPLETE
# 68877  68878  2014-07-08 00:00:00.0     6753  COMPLETE
# 68878  68879  2014-07-09 00:00:00.0      778  COMPLETE
# 68879  68880  2014-07-13 00:00:00.0     1117  COMPLETE
# 68882  68883  2014-07-23 00:00:00.0     5533  COMPLETE
#
# [30455 rows x 4 columns]

# %%
wo.query('status == ("COMPLETE","CLOSED") ')
# Out:
#        index                   date  orderID    status
# 0          1  2013-07-25 00:00:00.0    11599    CLOSED
# 2          3  2013-07-25 00:00:00.0    12111  COMPLETE
# 3          4  2013-07-25 00:00:00.0     8827    CLOSED
# 4          5  2013-07-25 00:00:00.0    11318  COMPLETE
# 5          6  2013-07-25 00:00:00.0     7130  COMPLETE
# ...      ...                    ...      ...       ...
# 68875  68876  2014-07-06 00:00:00.0     4124  COMPLETE
# 68877  68878  2014-07-08 00:00:00.0     6753  COMPLETE
# 68878  68879  2014-07-09 00:00:00.0      778  COMPLETE
# 68879  68880  2014-07-13 00:00:00.0     1117  COMPLETE
# 68882  68883  2014-07-23 00:00:00.0     5533  COMPLETE
#
# [30455 rows x 4 columns]

# %%
wo.query('status == "COMPLETE" and date  == "2013-07-25 00:00:00.0" and orderID > 1800 ')
# Out:
#        index                   date  orderID    status
# 2          3  2013-07-25 00:00:00.0    12111  COMPLETE
# 4          5  2013-07-25 00:00:00.0    11318  COMPLETE
# 5          6  2013-07-25 00:00:00.0     7130  COMPLETE
# 6          7  2013-07-25 00:00:00.0     4530  COMPLETE
# 14        15  2013-07-25 00:00:00.0     2568  COMPLETE
# 16        17  2013-07-25 00:00:00.0     2667  COMPLETE
# 25        26  2013-07-25 00:00:00.0     7562  COMPLETE
# 31        32  2013-07-25 00:00:00.0     3960  COMPLETE
# 34        35  2013-07-25 00:00:00.0     4840  COMPLETE
# 44        45  2013-07-25 00:00:00.0     2636  COMPLETE
# 55        56  2013-07-25 00:00:00.0    10519  COMPLETE
# 64        65  2013-07-25 00:00:00.0     5903  COMPLETE
# 70        71  2013-07-25 00:00:00.0     8646  COMPLETE
# 71        72  2013-07-25 00:00:00.0     4349  COMPLETE
# 75        76  2013-07-25 00:00:00.0     6898  COMPLETE
# 79        80  2013-07-25 00:00:00.0     3007  COMPLETE
# ...

# %%
wo. \
    groupby('status')['status']. \
    aggregate(counts ='count')
# Out:
#                  counts
# status
# CANCELED           1428
# CLOSED             7556
# COMPLETE          22899
# ON_HOLD            3798
# PAYMENT_REVIEW      729
# PENDING            7610
# PENDING_PAYMENT   15030
# PROCESSING         8275
# SUSPECTED_FRAUD    1558

# %%
wo['order_month'] = wo.apply(lambda x : x.date[:7], axis=1)

# %%
wo
# Out:
#        index                   date  orderID           status order_month
# 0          1  2013-07-25 00:00:00.0    11599           CLOSED     2013-07
# 1          2  2013-07-25 00:00:00.0      256  PENDING_PAYMENT     2013-07
# 2          3  2013-07-25 00:00:00.0    12111         COMPLETE     2013-07
# 3          4  2013-07-25 00:00:00.0     8827           CLOSED     2013-07
# 4          5  2013-07-25 00:00:00.0    11318         COMPLETE     2013-07
# ...      ...                    ...      ...              ...         ...
# 68878  68879  2014-07-09 00:00:00.0      778         COMPLETE     2014-07
# 68879  68880  2014-07-13 00:00:00.0     1117         COMPLETE     2014-07
# 68880  68881  2014-07-19 00:00:00.0     2518  PENDING_PAYMENT     2014-07
# 68881  68882  2014-07-22 00:00:00.0    10000          ON_HOLD     2014-07
# 68882  68883  2014-07-23 00:00:00.0     5533         COMPLETE     2014-07
#
# [68883 rows x 5 columns]

# %%
wo.columns
# Out:
# Index(['index', 'date', 'orderID', 'status', 'order_month'], dtype='object')

# %%
wo.groupby(['order_month', 'status'])['orderID'].agg(counts='count').reset_index()
# Out:
#     order_month           status  counts
# 0       2013-07         CANCELED      22
# 1       2013-07           CLOSED     161
# 2       2013-07         COMPLETE     515
# 3       2013-07          ON_HOLD      81
# 4       2013-07   PAYMENT_REVIEW      19
# ..          ...              ...     ...
# 112     2014-07   PAYMENT_REVIEW      54
# 113     2014-07          PENDING     517
# 114     2014-07  PENDING_PAYMENT     979
# 115     2014-07       PROCESSING     561
# 116     2014-07  SUSPECTED_FRAUD     101
#
# [117 rows x 3 columns]
